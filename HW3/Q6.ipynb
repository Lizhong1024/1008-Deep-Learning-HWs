# %% [markdown]
# ### Energy-based models assignment; implementation problem
#
# This is a (hopefully shorter, compared to hw2) implementation problem of the third assignment. We will investigate convolutional auto-encoders and denoising convolutional auto-encoders.

# %% [markdown]
# ### Prereqs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/'
# Out:
# /content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3

# %% [markdown]
# **Question 1 (of this notebook):**
#
# Estimated time: 10 min.
#
# We first load the data.
#
# TODO:
# - Print out a few shapes. See comments in the below cell. Can be done in three lines of code, but you're welcome to provide a more complicated solution.

# %%
import datetime
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import sys

import torch
import torch.nn as nn
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.utils import data
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms


def load_fashion_mnist(batch_size=64):
    # One convention (of the many) is to use a real number between -1 and 1
    # (inclusive) to represent each pixel; instead of an integer from 0 to 255.
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize([0.5], [0.5])])

    train_dataset = datasets.FashionMNIST(root='./data', train=True,
                                          download=True, transform=transform)

    # Create validation set from training set, given that torchvision only gives
    # us the train/test split.  
    num_train = len(train_dataset)
    indices = list(range(num_train))
    valid_size = 0.1
    split = int(np.floor(valid_size * num_train))

    random_seed = 123
    np.random.seed(random_seed)  # think: why do we do this?
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = data.SubsetRandomSampler(train_idx)
    valid_sampler = data.SubsetRandomSampler(valid_idx)
    train_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler)
    valid_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=valid_sampler)
    test_dataset = datasets.FashionMNIST(root='./data', train=False,
                                         download=True, transform=transform)
    test_loader = data.DataLoader(test_dataset, batch_size=batch_size,
                                  shuffle=False)
    
    # TODO: the images in training, validation, and test sets have shape:
    # [num of examples, image height, image weight];
    # write a few lines of code to print out the three (train/val/test) shapes;
    # for example, the test set image shape should be [10000, 28, 28];
    # try exploring the dataset using test_dataset[7], test_dataset.data, etc.
    print(train_dataset.data[train_idx].size())
    print(train_dataset.data[valid_idx].size())
    print(test_dataset.data.size())
    #raise NotImplementedError
    return train_loader, valid_loader, test_loader

def imshow(img):
    # First unnormalize if we want to print out the image. We're using the
    # convention that each image pixel is between -1 and 1. But when python
    # prints out images, the pixel needs to be between 0 and 1.
    img = img / 2 + 0.5
    img_numpy = img.numpy()
    plt.figure(figsize=(12, 12))
    plt.imshow(np.transpose(img_numpy, (1, 2, 0)))

# %%
batch_size = 64
train_loader, valid_loader, test_loader = load_fashion_mnist(batch_size)
# Out:
# torch.Size([54000, 28, 28])
# torch.Size([6000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
# !nvidia-smi  # make sure you're using GPUs when you are about to train the model
# Out:
# Fri Oct 30 19:20:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   77C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Taking a look at what the images are like
images = next(iter(test_loader))[0][:64]
imshow(torchvision.utils.make_grid(images, nrow=16))

# %% [markdown]
# Check out the ten classes on page 3: https://arxiv.org/pdf/1708.07747.pdf
# - 0: t-shirt/top; 1: trouser; 2: pullover; 3: dress; 4: coat; 5: sandals; 6: shirt; 7: sneaker; 8: bag; 9: ankle boots.
#
# <!-- For CIFAR10, check out the ten classes here: https://www.cs.toronto.edu/~kriz/cifar.html
# - Airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck -->
#
# This dataset is much more difficult on the classification task, compared to the digit MNIST which we saw in Lab 2. However, **today we will NOT be doing classification!!! So let's assume that the labels DO NOT EXIST in the iterators (the data loaders)!**

# %% [markdown]
# ### Model

# %% [markdown]
# Next, we will implement two versions of autoencoders: (1) convolutional autoencoder; (2) denoising convolutional autoencoder (but actually we'll be using the same model code, explained later).

# %% [markdown]
# **Question 2: implement a convolutional autoencoder**
#
# Estimated time: 30 min.
#
# TODO
# - In CAE class below, complete the init function and the forward function, such that your implementation satisfies the following requirements.
#   - The output image dimension (from the forward function) is exactly the same as the input image dimension.
#   - There are two Conv2d layer in the encoder, followed by three Conv2d or ConvTranspose2d blocks in the decoder. The out_channel for the second convolutional layer in the encoder should be >= 16 (for example, 16 or 32; feel free to experiment other choices).
#     - Use ReLU or some other similar nonlinearities, followed by pooling, after each convolution layer in the encoder.
#     - Use ReLU or some other similar nonlinearities, after each convolution layer in the decoder (except for the very last convolution layer). Suggestion (but no need to follow this advice): the out_channel size for the decoder convolutional layers should be smaller and smaller (meaning the out_channel for first decoding conv2d layer should be bigger than out_channel for second decoding conv2d layer).
#     - Add batch normalization layers after the nonlinearities, just like what you may have done in the previous homework.
#     - In decoder, if you want to obtain an output feature map with size larger than size of input feature map, consider using ConvTranspose2d, or UpsamplingBilinear2d, after figuring out what they do.
#     - No hard requirement on what padding or stride to use, but make sure they're small, given that our image is only 28*28.
#   - Note that your parameters (e.g., number of filters in the intermediate layers) should not be too big, given that our image is greyscale and has 28*28 pixels only.

# %%
cuda = torch.cuda.is_available()
device = torch.device('cuda' if cuda else 'cpu')

# %% [markdown]
# ##### Old Versions (Please Ignore)

# %%
######################################################
##############   Version 1    ########################
######################################################

class CAE_v1(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=8),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=16, out_channels=10, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=10)
        )
        self.decoder_2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=10, out_channels=5, kernel_size=9),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=5)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=5, out_channels=1, kernel_size=13)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %%
######################################################
##############   Version 2    ########################
# Increase num of channels based on Version 1
######################################################

class CAE_v2(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=32, out_channels=20, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=20)
        )
        self.decoder_2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=20, out_channels=6, kernel_size=9),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=6)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=6, out_channels=1, kernel_size=13)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %%
######################################################
##############   Version 3    ########################
# Decrease filter size based on Version 1
######################################################

class CAE_v3(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=8, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=8),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=16, out_channels=10, kernel_size=4),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=10)
        )
        self.decoder_2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=10, out_channels=5, kernel_size=9),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=5)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=5, out_channels=1, kernel_size=13)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %%
######################################################
##############   Version 4    ########################
# Add upsampling layer based on Version 2
######################################################

class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.ConvTranspose2d(in_channels=32, out_channels=20, kernel_size=3),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=20)
        )
        self.decoder_2 = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.ConvTranspose2d(in_channels=20, out_channels=6, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=6)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=6, out_channels=1, kernel_size=5)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %%
######################################################
##############   Version 5    ########################
# Put upsampling layer after ConvTranspose based on Version 4
######################################################

class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=32, out_channels=24, kernel_size=3),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=24),
            nn.UpsamplingBilinear2d(size=10)
        )
        self.decoder_2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=24, out_channels=10, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=10),
            nn.UpsamplingBilinear2d(size=24)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=10, out_channels=1, kernel_size=5)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %%
######################################################
##############   Version 6    ########################
# More channels based on Version 5
######################################################

class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=64),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.UpsamplingBilinear2d(size=10)
        )
        self.decoder_2 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=32, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.UpsamplingBilinear2d(size=24)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=16, out_channels=1, kernel_size=5)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %% [markdown]
# ##### Latest Version

# %%
######################################################
##############   Version 6.5    ########################
# More channels based on Version 4
######################################################

class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder_1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.MaxPool2d(kernel_size=2)
        )
        self.encoder_2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=64),
            nn.MaxPool2d(kernel_size=2)
        )

        self.decoder_1 = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.ConvTranspose2d(in_channels=64, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32)
        )
        self.decoder_2 = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.ConvTranspose2d(in_channels=32, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16)
        )
        self.decoder_3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=16, out_channels=1, kernel_size=5)
        )


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        bottleneck = self.encoder_1(y)
        #print(bottleneck.size())
        bottleneck = self.encoder_2(bottleneck)
        #print(bottleneck.size())

        yhat = self.decoder_1(bottleneck)
        #print(yhat.size())
        yhat = self.decoder_2(yhat)
        #print(yhat.size())
        yhat = self.decoder_3(yhat)
        #print(yhat.size())

        return yhat

# %% [markdown]
# Test Model

# %%
################### TEST ################
imshow(torchvision.utils.make_grid(images, nrow=16))

# %%
################### TEST ################
model = CAE().to(device)
images_hat = model(images.to(device))

# %%
################### TEST ################
images_hat = model(images.to(device))
imshow(torchvision.utils.make_grid(images_hat.detach().to('cpu'), nrow=16))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
################### TEST ################
images_hat[0].size()
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# **Question 3: complete the train() and validate() function to be used later**
#
# Estimated time: 10 min.
#
# TODO
# - Complete the train() function.
#   - Hint: recall the five steps we discussed in Lab 2.
#   - Make sure your images are on GPUs (device cuda) before you train. Otherwise, your training may be extremely extremely slow and it may take you 50 times longer than other people.
#
# - Complete the validate() function:
#   - The only thing we need to do is to save the model when we achieve the best validation loss so far. So, check out the pytorch documentation or the third lab, for how to save checkpoints. Make sure to do this step because we need to load the model later.

# %%
# This is part of question 4.
def add_noise(images):
    images_noisy = images.clone()

    noise = torch.randn(images.size())
    multipliers = torch.rand(images.size()[0]).view(-1, 1, 1, 1)
    noise = noise * multipliers
    
    images_noisy = images_noisy + noise
    images_noisy = torch.clamp(images_noisy, -1, 1)

    return images_noisy

# %%
################### TEST add_noise() ################
imshow(torchvision.utils.make_grid(images, nrow=16))

# %%
################### TEST add_noise() ################
images_noisy = add_noise(images)
imshow(torchvision.utils.make_grid(images_noisy, nrow=16))

# %%
def train(autoencoder, train_loader, epoch, num_epoch, learning_rate,
          log_interval, weight_decay=None, denoising=False):
    # Using sum reduction simply bc otherwise, the scale of the loss is too small;
    # given that we always have 28*28 images, using sum/mean reduction wouldn't
    # make a difference.
    criteria = nn.MSELoss(reduction='sum')
    optimizer = torch.optim.Adam(
        autoencoder.parameters(), lr=learning_rate)

    autoencoder.train()
    for i, data in enumerate(train_loader):
        #################################
        ######     My Code     ##########
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        
        input_images = input_images.to(device)
        images = images.to(device)

        images_hat = autoencoder(input_images)
        loss = criteria(images_hat, images)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #################################

        if (i + 1) % log_interval == 0:
            print('Epoch [{}/{}] - Iter[{}/{}], MSE loss:{:.6f}'.format(
                epoch + 1, num_epoch, i + 1,
                len(train_loader.dataset) // batch_size, loss.item() / batch_size
            ))
    return


def validate(autoencoder, valid_loader, best_val_loss, denoising=False, model_name='temp'):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(valid_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += loss
    avg_loss = total_loss / (len(valid_loader) * batch_size)

    print('\nLoss per batch on validation set: {:.6f}'.format(avg_loss))

    if avg_loss < best_val_loss:
        if denoising:
            save_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising'
        else:
            save_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder'
        best_val_loss = avg_loss
        ##############################
        #######    My Code   #########
        torch.save(
              {'loss': best_val_loss, 'model_state_dict': autoencoder.state_dict()},
              f'{save_path}/{model_name}.pt')
        ##############################
        print('Saved best model in the checkpoint directory\n')
    
    return best_val_loss

def evaluate(autoencoder, test_loader, denoising=False):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(test_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += loss
    avg_loss = total_loss / (len(test_loader) * batch_size)

    print('\nMSE loss per batch on test set: {:.6f}'.format(avg_loss))

# %% [markdown]
# **Question 4: implement a denoising convolutional autoencoder**
#
# Estimated time: 20 min.
#
# The input to a denoising CAE is a perturbed image, and the output is the original image. Given that we're using the same network, there's nothing we need to change about the CAE class.
#
# TODO
# - However, add an argument called ```denoising``` (defaulted to be ```False```) in the train() to indicate if our input will be the noisy version (in this case ```denoising=True```) or a clean version (in this case ```denoising=False```), and modify the functions appropriately, with the following instructions. Do the same for validate() and evaluate() to decide if we want to validate/evaluate on noisy or clean images.
#
# - Perturbation (i.e., making images noisy)
#   - First make sure that each pixels are represented by a real number from -1 to 1 (instead of integers from 0 to 255). The pixel should be already from -1 to 1, unless you did something you shouldn't have done.
#   - Next, do a perturbation to each image where the noise is sampled according to the standard Gaussian distribution and then multiplied by a number uniformly sampled from 0 to 1.
#     - In other words, each pixel in image i should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_i$ for some $c_i \in (0,1)$, and each pixel in image j should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_j$ for some $c_j \in (0,1)$. (In fact, the result is that for each image, we're still sampling the noise from a Gaussian distribution; the mean is 0, and the standard deviation is sampled from a uniform distribution. Think: why?)
#     - Make sure that the resulting perturbed/noisy image are still represented by numbers from -1 to 1 (so you may need to do some clipping with min -1 and max 1).
#
# - To add noise to a batch of images, please use a helper function called add_noise(), outside the train(), validate(), evaluate() functions.

# %% [markdown]
# **Question 5: Training**
#
# Estimated debugging time: 30 min, or longer if you have more severe bugs.
#
# TODO
#
# - Now, train your CAE model (where your input is the original images), and train your denoising CAE model (where your input is the noisy images). You can set a patience counter on your own (similar to homework 2), meaning if validation loss doesn't decrease for, say, 10 epochs (just an example), then you can stop training. Each training procedure may take half an hour or an hour. It may take many many more hours if you didn't move the model or the data onto GPUs. Moreover, to make sure your training is not lost in case colab disconnects, it's important to save checkpoints! Make sure you wrote the checkpoint saving code in the validate function.
# - Report the best validation loss. No need to plot the curve, but you can plot it nevertheless to have a better understanding on your training process.
#
# Estimated training time in total: 2 hours (depending on your model)?
# - Please do not spend the 2 hours staring at your log.
# - You don't need to get the "best" model. You only need Question 6, Question 7, and Question 8 to work. Q6 works if your reconstructed images aren't bad (okay to be blurry); Q7 works if your plots looks similar to the presented; Q8 works if ...please read Q8.

# %%
# version 6.5

batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100

denoising = False
keep_training_from_ckpt = False

if denoising:
    load_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising'
else:
    load_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder'
    
conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path))

patience_counter = 0
max_patience = 5
for epoch in range(num_epoch):
    if patience_counter >= max_patience: break
    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate, log_interval, denoising)
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    val_loss = validate(conv_autoencoder, valid_loader, best_val_loss, denoising)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
    else:
        patience_counter += 1
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:142.807159
# Epoch [1/100] - Iter[200/937], MSE loss:105.781693
# Epoch [1/100] - Iter[300/937], MSE loss:92.991058
# Epoch [1/100] - Iter[400/937], MSE loss:80.697021
# Epoch [1/100] - Iter[500/937], MSE loss:73.212311
# Epoch [1/100] - Iter[600/937], MSE loss:70.623672
# Epoch [1/100] - Iter[700/937], MSE loss:64.333221
# Epoch [1/100] - Iter[800/937], MSE loss:69.558319
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 62.325256
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:56.481758
# Epoch [2/100] - Iter[200/937], MSE loss:54.345772
# Epoch [2/100] - Iter[300/937], MSE loss:45.704880
# Epoch [2/100] - Iter[400/937], MSE loss:51.368568
# Epoch [2/100] - Iter[500/937], MSE loss:38.768749
# Epoch [2/100] - Iter[600/937], MSE loss:46.784126
# Epoch [2/100] - Iter[700/937], MSE loss:43.435284
# Epoch [2/100] - Iter[800/937], MSE loss:43.415779
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 36.417057
# Saved best model in the checkpoint directory
#
# Epoch [3/100] - Iter[100/937], MSE loss:38.014893
# Epoch [3/100] - Iter[200/937], MSE loss:47.358013
# Epoch [3/100] - Iter[300/937], MSE loss:38.594757
# Epoch [3/100] - Iter[400/937], MSE loss:46.731617
# Epoch [3/100] - Iter[500/937], MSE loss:32.373993
# Epoch [3/100] - Iter[600/937], MSE loss:32.468864
# Epoch [3/100] - Iter[700/937], MSE loss:34.425018
# Epoch [3/100] - Iter[800/937], MSE loss:33.027504
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 32.712868
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:29.989603
# Epoch [4/100] - Iter[200/937], MSE loss:32.662125
# Epoch [4/100] - Iter[300/937], MSE loss:35.956558
# Epoch [4/100] - Iter[400/937], MSE loss:45.759483
# Epoch [4/100] - Iter[500/937], MSE loss:33.270046
# Epoch [4/100] - Iter[600/937], MSE loss:31.910505
# Epoch [4/100] - Iter[700/937], MSE loss:36.547256
# Epoch [4/100] - Iter[800/937], MSE loss:29.485405
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 27.678812
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:28.709244
# Epoch [5/100] - Iter[200/937], MSE loss:31.097496
# Epoch [5/100] - Iter[300/937], MSE loss:33.276493
# Epoch [5/100] - Iter[400/937], MSE loss:28.011227
# Epoch [5/100] - Iter[500/937], MSE loss:27.126122
# Epoch [5/100] - Iter[600/937], MSE loss:29.881538
# Epoch [5/100] - Iter[700/937], MSE loss:25.927452
# Epoch [5/100] - Iter[800/937], MSE loss:28.678726
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 26.375805
# Saved best model in the checkpoint directory
#
# Epoch [6/100] - Iter[100/937], MSE loss:24.617779
# Epoch [6/100] - Iter[200/937], MSE loss:24.716030
# Epoch [6/100] - Iter[300/937], MSE loss:28.904402
# Epoch [6/100] - Iter[400/937], MSE loss:28.328001
# Epoch [6/100] - Iter[500/937], MSE loss:28.337208
# Epoch [6/100] - Iter[600/937], MSE loss:28.136383
# Epoch [6/100] - Iter[700/937], MSE loss:23.343575
# Epoch [6/100] - Iter[800/937], MSE loss:30.723829
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 24.649960
# Saved best model in the checkpoint directory
#
# Epoch [7/100] - Iter[100/937], MSE loss:25.075909
# Epoch [7/100] - Iter[200/937], MSE loss:25.123335
# Epoch [7/100] - Iter[300/937], MSE loss:25.911694
# Epoch [7/100] - Iter[400/937], MSE loss:25.929131
# Epoch [7/100] - Iter[500/937], MSE loss:27.562939
# Epoch [7/100] - Iter[600/937], MSE loss:30.118698
# Epoch [7/100] - Iter[700/937], MSE loss:29.190697
# Epoch [7/100] - Iter[800/937], MSE loss:23.049877
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set:
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 16.599747
# Saved best model in the checkpoint directory
#
# Epoch [49/100] - Iter[100/937], MSE loss:15.366842
# Epoch [49/100] - Iter[200/937], MSE loss:18.550461
# Epoch [49/100] - Iter[300/937], MSE loss:18.742844
# Epoch [49/100] - Iter[400/937], MSE loss:18.996475
# Epoch [49/100] - Iter[500/937], MSE loss:17.169817
# Epoch [49/100] - Iter[600/937], MSE loss:16.647320
# Epoch [49/100] - Iter[700/937], MSE loss:17.346825
# Epoch [49/100] - Iter[800/937], MSE loss:15.934612
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 16.909492
# Epoch [50/100] - Iter[100/937], MSE loss:15.757531
# Epoch [50/100] - Iter[200/937], MSE loss:16.860737
# Epoch [50/100] - Iter[300/937], MSE loss:14.997274
# Epoch [50/100] - Iter[400/937], MSE loss:17.626608
# Epoch [50/100] - Iter[500/937], MSE loss:22.208265
# Epoch [50/100] - Iter[600/937], MSE loss:17.089167
# Epoch [50/100] - Iter[700/937], MSE loss:17.635567
# Epoch [50/100] - Iter[800/937], MSE loss:19.975990
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 17.919035
# Epoch [51/100] - Iter[100/937], MSE loss:18.438011
# Epoch [51/100] - Iter[200/937], MSE loss:20.342171
# Epoch [51/100] - Iter[300/937], MSE loss:16.540852
# Epoch [51/100] - Iter[400/937], MSE loss:17.838516
# Epoch [51/100] - Iter[500/937], MSE loss:19.904728
# Epoch [51/100] - Iter[600/937], MSE loss:17.556633
# Epoch [51/100] - Iter[700/937], MSE loss:24.305861
# Epoch [51/100] - Iter[800/937], MSE loss:18.739342
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.132044
# Epoch [52/100] - Iter[100/937], MSE loss:18.110046
# Epoch [52/100] - Iter[200/937], MSE loss:15.121420
# Epoch [52/100] - Iter[300/937], MSE loss:14.356290
# Epoch [52/100] - Iter[400/937], MSE loss:18.750988
# Epoch [52/100] - Iter[500/937], MSE loss:18.334585
# Epoch [52/100] - Iter[600/937], MSE loss:15.579206
# Epoch [52/100] - Iter[700/937], MSE loss:22.094986
# Epoch [52/100] - Iter[800/937], MSE loss:17.535862
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 16.844328
# Epoch [53/100] - Iter[100/937], MSE loss:16.314285
# Epoch [53/100] - Iter[200/937], MSE loss:18.281483
# Epoch [53/100] - Iter[300/937], MSE loss:16.674168
# Epoch [53/100] - Iter[400/937], MSE loss:17.180656
# Epoch [53/100] - Iter[500/937], MSE loss:17.622337
# Epoch [53/100] - Iter[600/937], MSE loss:20.917503
# Epoch [53/100] - Iter[700/937], MSE loss:13.295841
# Epoch [53/100] - Iter[800/937], MSE loss:22.738438
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 17.159838
# Training done; best validation loss 16.5997

# %%
# version 6.5

batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100

denoising = True
keep_training_from_ckpt = False

if denoising:
    load_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising'
else:
    load_path = '/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder'
    
conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path))

patience_counter = 0
max_patience = 5
for epoch in range(num_epoch):
    if patience_counter >= max_patience: break

    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate, log_interval, denoising=denoising)
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    val_loss = validate(conv_autoencoder, valid_loader, best_val_loss, denoising=denoising)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
    else:
        patience_counter += 1
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:177.134109
# Epoch [1/100] - Iter[200/937], MSE loss:128.968658
# Epoch [1/100] - Iter[300/937], MSE loss:110.151352
# Epoch [1/100] - Iter[400/937], MSE loss:103.690994
# Epoch [1/100] - Iter[500/937], MSE loss:86.297935
# Epoch [1/100] - Iter[600/937], MSE loss:81.496765
# Epoch [1/100] - Iter[700/937], MSE loss:87.957802
# Epoch [1/100] - Iter[800/937], MSE loss:80.777695
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 73.743523
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:70.878220
# Epoch [2/100] - Iter[200/937], MSE loss:65.025246
# Epoch [2/100] - Iter[300/937], MSE loss:58.213314
# Epoch [2/100] - Iter[400/937], MSE loss:56.659309
# Epoch [2/100] - Iter[500/937], MSE loss:59.274269
# Epoch [2/100] - Iter[600/937], MSE loss:54.954880
# Epoch [2/100] - Iter[700/937], MSE loss:53.085934
# Epoch [2/100] - Iter[800/937], MSE loss:49.407486
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 50.839531
# Saved best model in the checkpoint directory
#
# Epoch [3/100] - Iter[100/937], MSE loss:43.207695
# Epoch [3/100] - Iter[200/937], MSE loss:52.482620
# Epoch [3/100] - Iter[300/937], MSE loss:47.177273
# Epoch [3/100] - Iter[400/937], MSE loss:49.614792
# Epoch [3/100] - Iter[500/937], MSE loss:56.092659
# Epoch [3/100] - Iter[600/937], MSE loss:45.136940
# Epoch [3/100] - Iter[700/937], MSE loss:43.542633
# Epoch [3/100] - Iter[800/937], MSE loss:40.233833
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 43.939976
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:41.447975
# Epoch [4/100] - Iter[200/937], MSE loss:46.643284
# Epoch [4/100] - Iter[300/937], MSE loss:43.697136
# Epoch [4/100] - Iter[400/937], MSE loss:39.774521
# Epoch [4/100] - Iter[500/937], MSE loss:41.300060
# Epoch [4/100] - Iter[600/937], MSE loss:42.758480
# Epoch [4/100] - Iter[700/937], MSE loss:41.860088
# Epoch [4/100] - Iter[800/937], MSE loss:38.521999
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 41.451488
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:40.946617
# Epoch [5/100] - Iter[200/937], MSE loss:42.484035
# Epoch [5/100] - Iter[300/937], MSE loss:44.748016
# Epoch [5/100] - Iter[400/937], MSE loss:41.901375
# Epoch [5/100] - Iter[500/937], MSE loss:35.777580
# Epoch [5/100] - Iter[600/937], MSE loss:40.235321
# Epoch [5/100] - Iter[700/937], MSE loss:41.738464
# Epoch [5/100] - Iter[800/937], MSE loss:41.509911
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 43.887661
# Epoch [6/100] - Iter[100/937], MSE loss:42.917507
# Epoch [6/100] - Iter[200/937], MSE loss:46.967850
# Epoch [6/100] - Iter[300/937], MSE loss:44.560074
# Epoch [6/100] - Iter[400/937], MSE loss:36.997169
# Epoch [6/100] - Iter[500/937], MSE loss:43.245045
# Epoch [6/100] - Iter[600/937], MSE loss:45.192749
# Epoch [6/100] - Iter[700/937], MSE loss:34.736500
# Epoch [6/100] - Iter[800/937], MSE loss:34.390060
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 38.045582
# Saved best model in the checkpoint directory
#
# Epoch [7/100] - Iter[100/937], MSE loss:48.973579
# Epoch [7/100] - Iter[200/937], MSE loss:36.267288
# Epoch [7/100] - Iter[300/937], MSE loss:43.063423
# Epoch [7/100] - Iter[400/937], MSE loss:42.755898
# Epoch [7/100] - Iter[500/937], MSE loss:37.564987
# Epoch [7/100] - Iter[600/937], MSE loss:53.411114
# Epoch [7/100] - Iter[700/937], MSE loss:43.124870
# Epoch [7/100] - Iter[800/937], MSE loss:41.953403
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 37.876236
# Saved best model in the checkpoint directory
#
# Epoch [8/100] - Iter[100/937], MSE loss:44.748077
# Epoch [8/100] - Iter[200/937], MSE loss:40.367397
# Epoch [8/100] - Iter[300/937], MSE loss:39.798187
# Epoch [8/100] - Iter[400/937], MSE loss:42.219635
# Epoch [8/100] - Iter[500/937], MSE loss:34.520653
# Epoch [8/100] - Iter[600/937], MSE loss:41.268700
# Epoch [8/100] - Iter[700/937], MSE loss:40.820999
# Epoch [8/100] - Iter[800/937], MSE loss:42.925995
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 37.170296
# Saved best model in the checkpoint directory
#
# Epoch [9/100] - Iter[100/937], MSE loss:29.969694
# Epoch [9/100] - Iter[200/937], MSE loss:34.979034
# Epoch [9/100] - Iter[300/937], MSE loss:34.476269
# Epoch [9/100] - Iter[400/937], MSE loss:39.636108
# Epoch [9/100] - Iter[500/937], MSE loss:41.316833
# Epoch [9/100] - Iter[600/937], MSE loss:37.087959
# Epoch [9/100] - Iter[700/937], MSE loss:35.930939
# Epoch [9/100] - Iter[800/937], MSE loss:38.945705
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 40.612778
# Epoch [10/100] - Iter[100/937], MSE loss:38.916527
# Epoch [10/100] - Iter[200/937], MSE loss:35.024662
# Epoch [10/100] - Iter[300/937], MSE loss:39.914909
# Epoch [10/100] - Iter[400/937], MSE loss:36.218781
# Epoch [10/100] - Iter[500/937], MSE loss:40.592411
# Epoch [10/100] - Iter[600/937], MSE loss:45.446281
# Epoch [10/100] - Iter[700/937], MSE loss:39.318901
# Epoch [10/100] - Iter[800/937], MSE loss:35.516190
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 35.902393
# Saved best model in the checkpoint directory
#
# Epoch [11/100] - Iter[100/937], MSE loss:40.702141
# Epoch [11/100] - Iter[200/937], MSE loss:34.726116
# Epoch [11/100] - Iter[300/937], MSE loss:37.680660
# Epoch [11/100] - Iter[400/937], MSE loss:36.424137
# Epoch [11/100] - Iter[500/937], MSE loss:39.473598
# Epoch [11/100] - Iter[600/937], MSE loss:33.899685
# Epoch [11/100] - Iter[700/937], MSE loss:37.259468
# Epoch [11/100] - Iter[800/937], MSE loss:35.811985
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 36.941242
# Epoch [12/100] - Iter[100/937], MSE loss:41.860825
# Epoch [12/100] - Iter[200/937], MSE loss:36.409912
# Epoch [12/100] - Iter[300/937], MSE loss:38.639397
# Epoch [12/100] - Iter[400/937], MSE loss:35.408894
# Epoch [12/100] - Iter[500/937], MSE loss:37.895142
# Epoch [12/100] - Iter[600/937], MSE loss:37.156921
# Epoch [12/100] - Iter[700/937], MSE loss:39.120285
# Epoch [12/100] - Iter[800/937], MSE loss:36.008545
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 35.741455
# Saved best model in the checkpoint directory
#
# Epoch [13/100] - Iter[100/937], MSE loss:39.791870
# Epoch [13/100] - Iter[200/937], MSE loss:35.018127
# Epoch [13/100] - Iter[300/937], MSE loss:35.428696
# Epoch [13/100] - Iter[400/937], MSE loss:37.262371
# Epoch [13/100] - Iter[500/937], MSE loss:37.493599
# Epoch [13/100] - Iter[600/937], MSE loss:35.214592
# Epoch [13/100] - Iter[700/937], MSE loss:43.796913
# Epoch [13/100] - Iter[800/937], MSE loss:35.314468
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 35.705055
# Saved best model in the checkpoint directory
#
# Epoch [14/100] - Iter[100/937], MSE loss:35.739079
# Epoch [14/100] - Iter[200/937], MSE loss:41.596306
# Epoch [14/100] - Iter[300/937], MSE loss:34.777626
# Epoch [14/100] - Iter[400/937], MSE loss:34.126694
# Epoch [14/100] - Iter[500/937], MSE loss:36.718315
# Epoch [14/100] - Iter[600/937], MSE loss:35.879925
# Epoch [14/100] - Iter[700/937], MSE loss:34.791695
# Epoch [14/100] - Iter[800/937], MSE loss:42.619717
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 35.320339
# Saved best model in the checkpoint directory
#
# Epoch [15/100] - Iter[100/937], MSE loss:36.607456
# Epoch [15/100] - Iter[200/937], MSE loss:31.253315
# Epoch [15/100] - Iter[300/937], MSE loss:34.873631
# Epoch [15/100] - Iter[400/937], MSE loss:34.438911
# Epoch [15/100] - Iter[500/937], MSE loss:34.835030
# Epoch [15/100] - Iter[600/937], MSE loss:38.460907
# Epoch [15/100] - Iter[700/937], MSE loss:40.967194
# Epoch [15/100] - Iter[800/937], MSE loss:37.525257
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 34.649094
# Saved best model in the checkpoint directory
#
# Epoch [16/100] - Iter[100/937], MSE loss:33.108116
# Epoch [16/100] - Iter[200/937], MSE loss:36.005783
# Epoch [16/100] - Iter[300/937], MSE loss:40.500004
# Epoch [16/100] - Iter[400/937], MSE loss:34.720589
# Epoch [16/100] - Iter[500/937], MSE loss:36.366470
# Epoch [16/100] - Iter[600/937], MSE loss:37.280518
# Epoch [16/100] - Iter[700/937], MSE loss:38.898117
# Epoch [16/100] - Iter[800/937], MSE loss:36.845737
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 34.475952
# Saved best model in the checkpoint directory
#
# Epoch [17/100] - Iter[100/937], MSE loss:36.020275
# Epoch [17/100] - Iter[200/937], MSE loss:33.634071
# Epoch [17/100] - Iter[300/937], MSE loss:39.037102
# Epoch [17/100] - Iter[400/937], MSE loss:37.253181
# Epoch [17/100] - Iter[500/937], MSE loss:39.143738
# Epoch [17/100] - Iter[600/937], MSE loss:35.574059
# Epoch [17/100] - Iter[700/937], MSE loss:36.150414
# Epoch [17/100] - Iter[800/937], MSE loss:35.157547
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set:
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 32.473576
# Epoch [41/100] - Iter[100/937], MSE loss:31.944124
# Epoch [41/100] - Iter[200/937], MSE loss:29.891972
# Epoch [41/100] - Iter[300/937], MSE loss:34.427109
# Epoch [41/100] - Iter[400/937], MSE loss:34.667610
# Epoch [41/100] - Iter[500/937], MSE loss:33.105659
# Epoch [41/100] - Iter[600/937], MSE loss:36.046135
# Epoch [41/100] - Iter[700/937], MSE loss:32.677582
# Epoch [41/100] - Iter[800/937], MSE loss:38.331314
# Trained this epoch using 12 seconds
#
# Loss per batch on validation set: 32.280983
# Training done; best validation loss 32.1310

# %% [markdown]
# **Question 6: evaluate on test sets**
#
# Estimated time: 10 min.
#
# Only run the below cell when you're done with training, and you're evaluating on test sets.
#
# TODO:
# - Print out the reconstruction loss on test set for both the CAE and denoising CAE models.
# - Print out a few reconstructed images (for both models). Here, the input to CAE should be clean images; the input to denoising CAE should be noisy images. It's perfectly fine if your reconstructed images are blurry. If your reconstructed image is extremely bad (for example, if you absolutely can't tell what object it is anymore), then you probably made a mistake in the previous steps. You might have chosen an overly small out_channel, for example. Or, learning might be inadequate. Or, you made a mistake in model saving / model loading.

# %%
# Only run at evaluation time!

def print_loss_and_reconstructed_images(denoising, model_name):
    conv_autoencoder = CAE().to(device)
    
    if denoising:
        #conv_autoencoder.load_state_dict(torch.load('/content/drive/My Drive/colabs/prep-dl-fall20-hw3/checkpoint/conv_autoencoder_new_denoising.pt'))
        conv_autoencoder.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising/{model_name}.pt')['model_state_dict'])
    else:
        #conv_autoencoder.load_state_dict(torch.load('/content/drive/My Drive/colabs/prep-dl-fall20-hw3/checkpoint/conv_autoencoder_new_0.pt'))
        conv_autoencoder.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder/{model_name}.pt')['model_state_dict'])
    if cuda:
        conv_autoencoder.cuda()
    # TODO: evaluate on test set and print out reconstruction loss
    total_loss = 0
    total_num_images = 0
    criteria = nn.MSELoss(reduction='sum')
    conv_autoencoder.eval()

    for i, data in enumerate(test_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        
        images_hat = conv_autoencoder(input_images)
        loss = criteria(images_hat, images)
        
        total_loss += loss.item()
        total_num_images += images.size()[0]
    
    print('[LOSS] Total reconstruction loss is ', total_loss)
    print('[LOSS] Average reconstruction loss is ', total_loss/total_num_images)

    conv_autoencoder.cpu()
    # TODO: print out a few (perhaps 16 or 32) reconstructed images for both models
    data = next(iter(test_loader))
    images = data[0][:32]
    if denoising:
        input_images = add_noise(images)
    else:
        input_images = images
    input_images = input_images.detach().cpu()
    images_hat = conv_autoencoder(input_images)
    
    plt.figure()
    imshow(torchvision.utils.make_grid(input_images.detach().to('cpu'), nrow=16))
    plt.figure()
    imshow(torchvision.utils.make_grid(images_hat.detach().to('cpu'), nrow=16))

# %%
print_loss_and_reconstructed_images(False, 'model_6.5')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [LOSS] Total reconstruction loss is  167137.64785766602
# [LOSS] Average reconstruction loss is  16.713764785766603

# %%
print_loss_and_reconstructed_images(True, 'model_6.5')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [LOSS] Total reconstruction loss is  324816.5411376953
# [LOSS] Average reconstruction loss is  32.48165411376953

# %% [markdown]
# ### Plotting loss vs. noise length

# %% [markdown]
# **Question 7: plot loss vs. noise length**
#
# Estimated time: 30 min.
#
# TODO:
# For both CAE and denoising CAE models you trained, plot loss vs. noise length, for five different images in five separate plots.
# - Terminology
#   - The noise length is the L2 norm of the noise you added to the image. So, it will be the norm of image_noisy minus image.
#   - The loss refers to the reconstruction loss.
#
# - For each image...
#   - **In this part, the input to both CAE and denoising CAE should be noisy images.** But how much noise?
#   - For each image, at least add 100 different noises with different length (so we're doing at least 100 "trials"). Perhaps you can use different standard deviations in the Gaussian distribution (when you add the noise into the images). For example, you can refer to the provided add_noise_coeff function with coeff as an input argument. You don't need to use this function.
#   - Compute the reconstruction loss for each noise you added.
#   - Now you would have the following list [(noise length #1, loss #1), (noise length #2, loss #2), ..., (noise length #n, loss #n)] (where n is at least 100) for CAE. You should have a similar list for denoising CAE. Now plot the loss (vertical axis) and length (horizontal axis), of two models, in the same plot. But note that the plot only corresponds to one original clean image.
#
# - Do the above for 3 different images.
#
# - Feel free to use get_length_and_loss as a template. However, absolutely no need to follow the logic of get_length_and_loss.
#
# - For each image, you should see a plot similar to the below trend. Think: why? No need to explain.

# %%
def add_noise_coeff(images, coeff):
    images_noisy = images.clone().to('cpu')
    noise = torch.mul(
        torch.randn(images.shape),
        torch.tensor([coeff]).view(-1, 1, 1, 1))
    images_noisy = images_noisy + noise
    images_noisy = torch.clamp(images_noisy, -1.0, 1.0)
    return images_noisy

# %%
def calculate_noise_length(images, images_noisy):
    noise_length = torch.norm(images-images_noisy, p=2, dim=(-2,-1)) # [batch_size, 1]
    return noise_length.squeeze()

# %%
def get_length_and_loss(images, denoising, model_name, debug=False):
    loss_ae = []
    length_ae = []
    autoencoder = CAE().to(device)
    images = images.to(device)

    images_noisy_list = []
    images_hat_list = []

    if denoising:
        autoencoder.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising/{model_name}.pt')['model_state_dict'])
    else:
        autoencoder.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder/{model_name}.pt')['model_state_dict'])
    if cuda:
        autoencoder.cuda()
    
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    
    while len(length_ae) < 100:
        
        # find a new noise length
        coefficient = torch.rand(1).item()*1.5
        images_noisy = add_noise_coeff(images, coefficient).to(device)
        noise_length = calculate_noise_length(images, images_noisy).item()
        while noise_length in length_ae:
            coefficient = torch.rand(1).item()*1.5
            images_noisy = add_noise_coeff(images, coefficient)
            noise_length = calculate_noise_length(images, images_noisy)
        
        # reconstruct image & calculate loss
        images_hat = autoencoder(images_noisy)
        loss = criteria(images_hat, images).item()
        
        loss_ae.append(loss)
        length_ae.append(noise_length)
        if debug:
            images_noisy_list.append(images_noisy.detach().to('cpu'))
            images_hat_list.append(images_hat.detach().to('cpu'))

    if debug:
        return loss_ae, length_ae, images_noisy_list, images_hat_list
    else:
        return loss_ae, length_ae

# %%
# Taking a look at what the images are like
images = next(iter(test_loader))[0][:64]
imshow(torchvision.utils.make_grid(images, nrow=16))

# %% [markdown]
# ### Model 6.5

# %% [markdown]
# ##### Image 1

# %%
input_image = images[1].detach().to('cpu')
plt.imshow(input_image.squeeze(), cmap='gray')

# %%
loss_cae, length_cae = get_length_and_loss(input_image.unsqueeze(0), denoising=False, model_name='model_6.5')
loss_dcae, length_dcae = get_length_and_loss(input_image.unsqueeze(0), denoising=True, model_name='model_6.5')

# %%
plt.figure(figsize=(8,5))
plt.scatter(length_cae, loss_cae, label='CAE')
plt.scatter(length_dcae, loss_dcae, label='denoising CAE')
plt.xlabel('Noise length')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### Image 2

# %%
input_image = images[30].detach().to('cpu')
plt.imshow(input_image.squeeze(), cmap='gray')
plt.show()

# %%
loss_cae, length_cae = get_length_and_loss(input_image.unsqueeze(0), denoising=False, model_name='model_6.5')
loss_dcae, length_dcae = get_length_and_loss(input_image.unsqueeze(0), denoising=True, model_name='model_6.5')

# %%
plt.figure(figsize=(8,5))
plt.scatter(length_cae, loss_cae, label='CAE')
plt.scatter(length_dcae, loss_dcae, label='denoising CAE')
plt.xlabel('Noise length')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### image 3

# %%
input_image = images[5].detach().to('cpu')
plt.imshow(input_image.squeeze(), cmap='gray')
plt.show()

# %%
loss_cae, length_cae = get_length_and_loss(input_image.unsqueeze(0), denoising=False, model_name='model_6.5')
loss_dcae, length_dcae = get_length_and_loss(input_image.unsqueeze(0), denoising=True, model_name='model_6.5')

# %%
plt.figure(figsize=(8,5))
plt.scatter(length_cae, loss_cae, label='CAE')
plt.scatter(length_dcae, loss_dcae, label='denoising CAE')
plt.xlabel('Noise length')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### image 4

# %%
input_image = images[0].detach().to('cpu')
plt.imshow(input_image.squeeze(), cmap='gray')
plt.show()

# %%
loss_cae, length_cae = get_length_and_loss(input_image.unsqueeze(0), denoising=False, model_name='model_6.5')
loss_dcae, length_dcae = get_length_and_loss(input_image.unsqueeze(0), denoising=True, model_name='model_6.5')

# %%
plt.figure(figsize=(8,5))
plt.scatter(length_cae, loss_cae, label='CAE')
plt.scatter(length_dcae, loss_dcae, label='denoising CAE')
plt.xlabel('Noise length')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ##### Compare reconstructed images

# %%
input_image = images[1].detach().to('cpu')
plt.imshow(input_image.squeeze(), cmap='gray')

# %%
loss_cae, length_cae, images_noisy_cae, output_image_cae = get_length_and_loss(input_image.unsqueeze(0), denoising=False, model_name='model_6.5', debug=True)
loss_dcae, length_dcae, images_noisy_dcae, output_image_dcae = get_length_and_loss(input_image.unsqueeze(0), denoising=True, model_name='model_6.5', debug=True)

# Load two models
model_name = 'model_6.5'
cae = CAE().to(device)
cae.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/convolutional_autoencoder/{model_name}.pt')['model_state_dict'])
dcae = CAE().to(device)
dcae.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising/{model_name}.pt')['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# Input noisy image
images_noisy = images_noisy_dcae[0]
plt.imshow(images_noisy.detach().to('cpu').squeeze(), cmap='gray')
plt.show()

# %%
# Non-denoising Model
plt.imshow(cae(images_noisy.to(device)).detach().to('cpu').squeeze(), cmap='gray')
plt.show()

# %%
# Denoising Model
plt.imshow(dcae(images_noisy.to(device)).detach().to('cpu').squeeze(), cmap='gray')
plt.show()

# %% [markdown]
# ### Visualizing interpolation

# %% [markdown]
# Congrats on getting this far! Here is a final question.
#
# **Question 8: interpolating latents**
#
# Estimated time: 30 min to 1 hour.
#
# Suppose the encoder is E, decoder is D. We essentially did the following: yhat = D(E(y)) where y is the input and yhat is the reconstructed image.
#
# Let z = E(y), so z is called the latent. Specifically, we obtain z after the batch normalization / pooling layers of the encoder.
#
# Now, let's try interpolating the z for one image and the z for another image!
#
# TODO:
# - Suppose the 0th image in the test set is called y0, and the 1st image in the test set is called y1. They correspond to latents z0 and z1 respectively.
# - Now, set new z by one of the following eleven choices and then print out the reconstructed image.
#   - z = 0.0 * z0 + 1.0 * z1
#   - z = 0.1 * z0 + 0.9 * z1
#   - z = 0.2 * z0 + 0.8 * z1
#   - ...
#   - z = 1.0 * z0 + 0.0 * z1
# - So, your result (to be submitted) should be...
#   - an image generated by the following latent: z = 0.0 * z0 + 1.0 * z1
#   - an image generated by the following latent: z = 0.1 * z0 + 0.9 * z1
#   - ...
#   - an image generated by the following latent: z = 1.0 * z0 + 0.0 * z1
# - Hint: you should see that your images gradually change from y1 to y0. If y1 is a tshirt and y0 is a shoe, then you should see that the images change gradually from a tshirt to a shoe.
# - You only need to do this for the regular CAE.
# - Explain clearly what your y1 is, and what your y0 is.
#
#
#
#
#
# Here is some code which may be helpful. You don't need to use the below.
# ```
#     model_children = list(model.children())
#     print("model children: ", model_children)
# ```
# You can use elements in model_children to process your inputs. You can also add another helper function (other than init and forward) in the CAE class. Your call!

# %%
model_name = 'model_6.5'
autoencoder = CAE()
autoencoder.load_state_dict(torch.load(f'/content/drive/My Drive/Fall 2020/1008 Deep Learning/HWs/HW3/saved_models/denoising/{model_name}.pt')['model_state_dict'])
autoencoder = autoencoder.cpu()

# %%
def visualize_one_model(model, image1, image2, gamma1):
    
    model_children = list(model.children())
    encoder = model_children[:2]
    decoder = model_children[2:]

    z1 = image1.clone().unsqueeze(0)
    z2 = image2.clone().unsqueeze(0)
    for layer in encoder:
        z1 = layer(z1)
        z2 = layer(z2)
    
    z = z1 * gamma1 + z2 * (1-gamma1)

    output = z.clone()
    for layer in decoder:
        output = layer(output)
    
    plt.imshow(output.detach().to('cpu').squeeze(), cmap='gray')
    plt.show()
    return

# %%
image1 = images[1]
image2 = images[9]

# %%
plt.imshow(image1.detach().to('cpu').squeeze(), cmap='gray')
plt.show()

# %%
plt.imshow(image2.detach().to('cpu').squeeze(), cmap='gray')
plt.show()

# %%
for k in np.arange(0, 1.01, 0.1):
  print('k =', k)
  visualize_one_model(autoencoder, image1, image2, k)
# Out:
# k = 0.0
# k = 0.1
# k = 0.2
# k = 0.30000000000000004
# k = 0.4
# k = 0.5
# k = 0.6000000000000001
# k = 0.7000000000000001
# k = 0.8
# k = 0.9
# k = 1.0

# %% [markdown]
# My y0 is a shirt, and my y1 is a shoe
